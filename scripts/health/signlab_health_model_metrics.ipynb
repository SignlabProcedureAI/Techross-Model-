# %%
import sys
import os

model_upgrading_path = os.path.join("..","..","src")
sys.path.append(model_upgrading_path)

# %%
import sys
import os

model_upgrading_path = os.path.join("..","..","src")
sys.path.append(model_upgrading_path)
import sys
import os

model_upgrading_path = os.path.join("..","..","src")
sys.path.append(model_upgrading_path)

#  moduel
from my_package.model import health_model
from my_package.data.select_dataset import get_dataframe_from_database

# basic
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# model
from sklearn.metrics import confusion_matrix

# %%
# 데이터 로드
data = get_dataframe_from_database('signlab','tc_ai_fts_model_system_health_group',all=True)

# %%
data['DIFF'] = np.abs(data['ACTUAL'] - data['PRED'])

# %%
data['DIFF'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>
